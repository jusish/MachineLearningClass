# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import style

df = pd.read_csv('ml.csv')
df.head()
# Out:
#    Unnamed: 0                vin manufacturer  year            color  \
# 0           0  QPHT622T547G7YY51    Chevrolet  1999           orange
# 1           1  USILGOGS66KQDI8AS       Toyota  1992            black
# 2           2  4H0LUVAZE5ZKU6B8C   Volkswagen  1991             blue
# 3           3  HKQU9VN0D0WYTD4P1       Toyota  1994             gray
# 4           4  UC1OGL1I0CET7OHZP         Audi  2000  metallic_silver
#
#      body_type engine_type transmission  fuel_type  seating_capacity  \
# 0  Convertible    electric       manual  biodiesel                 7
# 1          SUV      diesel       manual     hybrid                 8
# 2        Wagon      diesel    automatic     hybrid                 8
# 3    Hatchback      petrol       manual   gasoline                 3
# 4        Sedan      petrol       manual   hydrogen                 5
#
#    kilometers_driven vehicle_condition_status  selling_price  \
# 0              84.65                   active         256.19
# 1              57.65                   active         159.80
# 2              38.08                 inactive         293.10
# 3              34.99                 inactive         729.63
# 4              27.93                   active         418.36
#
#                  owner_name owner_profession  owner_age   owner_district  \
# 0    KANEZA Michele Phoenix  agriculturalist         65  kigali_kicukiro
# 1        UHIRIWE CHRISOSTOM           writer         40     west_karongi
# 2           IRIBAGIZA Fanny       journalist         64  south_nyamagabe
# 3  UWUMUGISHA Heloise Rugie         engineer         53    south_kamonyi
# 4      NDAYISHIMIYE Gilbert       blacksmith         70      east_kirehe
#
#    purchase_price purchase_date
# 0          256.19    2018-02-15
# 1          159.80    2005-11-14
# 2          293.10    2019-02-04
# 3          729.63    2002-03-07
# 4          418.36    2018-09-04

# %%
df.tail()
# Out:
#      Unnamed: 0                vin manufacturer  year          color  \
# 295         295  UGJLTEX6YMYLRXCLS     Mercedes  1998           gold
# 296         296  4A6534OLZNR99OGWN   Volkswagen  1995  metallic_gray
# 297         297  FSW8H0REGM6N05PTF    Chevrolet  1994         chrome
# 298         298  1QCA44W8UVCYHLLIH         Ford  1996           blue
# 299         299  03Y6KT7Y3GRCXHQC8         Audi  2000    matte_black
#
#     body_type engine_type transmission  fuel_type  seating_capacity  \
# 295     Wagon    electric    automatic   electric                 2
# 296     Truck    electric       manual    ethanol                 2
# 297       Van      petrol       manual  biodiesel                 7
# 298     Wagon      diesel       manual    ethanol                10
# 299     Coupe    electric    automatic   gasoline                 2
#
#      kilometers_driven vehicle_condition_status  selling_price  \
# 295              65.57                   active         704.82
# 296              95.64                   active         814.13
# 297              64.54                   active         562.64
# 298               2.05                   active         623.75
# 299               2.12                   active        2000.12
#
#                            owner_name owner_profession  owner_age  \
# 295                 MANISHIMWE Yvette        biologist         73
# 296      NSHUTI ISHIMWE ANGELO JOSEPH          plumber         90
# 297             BIGWI SHYAKA Valentin         designer        100
# 298  BIENVENUE ALLIANCE DIEU D' AMOUR           waiter         67
# 299                    UMWALI Cynthia          surgeon         58
#
#      owner_district  purchase_price purchase_date
# 295    east_gatsibo          866.11    2013-04-08
# 296  west_ngororero          814.13    2017-12-07
# 297     east_kirehe          706.57    2012-12-27
# 298  east_rwamagana          864.45    2002-03-01
# 299    west_rutsiro          953.99    2023-10-22

# %%
df.describe()
# Out:
#        Unnamed: 0         year  seating_capacity  kilometers_driven  \
# count  300.000000   300.000000        300.000000          300.00000
# mean   149.500000  1995.123333          5.990000           47.34220
# std     86.746758     3.168847          2.564858           28.76801
# min      0.000000  1990.000000          2.000000            0.21000
# 25%     74.750000  1992.000000          4.000000           23.01000
# 50%    149.500000  1995.000000          6.000000           44.12500
# 75%    224.250000  1998.000000          8.000000           70.49750
# max    299.000000  2000.000000         10.000000           99.87000
#
#        selling_price   owner_age  purchase_price
# count     300.000000  300.000000      300.000000
# mean      578.797033   59.756667      634.430600
# std       261.021393   23.845324      262.872937
# min        37.690000   18.000000       37.690000
# 25%       380.797500   40.750000      417.857500
# 50%       574.575000   61.000000      630.220000
# 75%       782.710000   80.000000      851.655000
# max      2000.120000  100.000000     1188.860000

# %%
df.shape
# Out:
# (300, 19)

# %%
categorical_columns = df.select_dtypes(include=["object"]).columns
for col in categorical_columns:
    unique_values = df[col].unique()
    print(f"{col}: {len(unique_values)} unique values")
# Out:
# vin: 300 unique values
# manufacturer: 10 unique values
# color: 23 unique values
# body_type: 8 unique values
# engine_type: 3 unique values
# transmission: 2 unique values
# fuel_type: 7 unique values
# vehicle_condition_status: 2 unique values
# owner_name: 123 unique values
# owner_profession: 86 unique values
# owner_district: 30 unique values
# purchase_date: 293 unique values

# %%
for col in df.columns:
    print(df[col].value_counts())
# Out:
# Unnamed: 0
# 0      1
# 206    1
# 204    1
# 203    1
# 202    1
#       ..
# 99     1
# 98     1
# 97     1
# 96     1
# 299    1
# Name: count, Length: 300, dtype: int64
# vin
# QPHT622T547G7YY51    1
# OYV64IGWC0JDZECSS    1
# QWSRKTC93Y7MPTR4H    1
# 0RNDMCVJGXJXQQDH7    1
# UN1UILJSN0X4HSKPA    1
#                     ..
# VWIYPTLQ548LT1SX5    1
# Q819LEYWSK10YWAKM    1
# XZCJCJ3IA0NBEF1OK    1
# X5CYZ50S0CG35M7GK    1
# 03Y6KT7Y3GRCXHQC8    1
# Name: count, Length: 300, dtype: int64
# manufacturer
# Chevrolet     38
# Audi          36
# Ford          36
# Toyota        33
# Honda         30
# Hyundai       28
# BMW           27
# Volkswagen    25
# Nissan        24
# Mercedes      23
# Name: count, dtype: int64
# year
# 2000    31
# 1993    31
# 1992    30
# 1991    30
# 1999    28
# 1998    28
# 1996    27
# 1997    27
# 1995    25
# 1994    23
# 1990    20
# Name: count, dtype: int64
# color
# blue               24
# gray               18
# metallic_silver    16
# black              16
# orange             15
# metallic_brown     15
# metallic_gray      15
# metallic_green     15
# green              14
# chrome             14
# brown              14
# yellow             13
# gold               12
# matte_black        12
# metallic_black     11
# pearl_white        11
# purple             11
# metallic_red       11
# silver             10
# metallic_blue       9
# red                 8
# white               8
# custom              8
# Name: count, dtype: int64
# body_type
# Sedan          47
# SUV            44
# Truck          41
# Wagon          39
# Convertible    35
# Hatchback      32
# Coupe          32
# Van            30
# Name: count, dtype: int64
# engine_type
# petrol      105
# electric    100
# diesel       95
# Name: count, dtype: int64
# transmission
# manual       162
# automatic    138
# Name: count, dtype: int64
# fuel_type
# hybrid       49
# biodiesel    45
# gasoline     44
# diesel       42
# ethanol      42
# hydrogen     40
# electric     38
# Name: count, dtype: int64
# seating_capacity
# 7     43
# 4     39
# 9     38
# 8     34
# 3     34
# 2     33
# 6     28
# 10    27
# 5     24
# Name: count, dtype: int64
# kilometers_driven
# 62.74    2
# 2.12     2
# 24.44    2
# 21.66    2
# 30.01    1
#         ..
# 95.34    1
# 28.65    1
# 57.61    1
# 84.37    1
# 2.05     1
# Name: count, Length: 296, dtype: int64
# vehicle_condition_status
# active      153
# inactive    147
# Name: count, dtype: int64
# selling_price
# 256.19     1
# 806.34     1
# 772.49     1
# 701.90     1
# 206.41     1
#           ..
# 734.61     1
# 323.62     1
# 544.23     1
# 457.73     1
# 2000.12    1
# Name: count, Length: 300, dtype: int64
# owner_name
# NSHUTI MULINDWA Christian       8
# TUYUBAHE EDOUARD                7
# ISIMBI KEZA Lysa                5
# USHIMIRWA INGABIRE Benitha      5
# DUKUNDANE FURAHA Yves Derick    5
#                                ..
# BANA EMMY TRESOR                1
# ISHIMWE AMANI Samuel            1
# BUGINGO ERIC DERICK             1
# IRASUBIZA MUCYO Bertrand        1
# UWASE TETA Paola                1
# Name: count, Length: 123, dtype: int64
# owner_profession
# actress           8
# lawyer            7
# cleaner           7
# firefighter       7
# programmer        6
#                  ..
# musician          1
# pharmacist        1
# accountant        1
# police_officer    1
# interpreter       1
# Name: count, Length: 86, dtype: int64
# owner_age
# 62     9
# 80     8
# 100    7
# 73     7
# 30     7
#       ..
# 68     2
# 31     1
# 71     1
# 34     1
# 83     1
# Name: count, Length: 81, dtype: int64
# owner_district
# east_rwamagana       16
# south_gisagara       14
# west_nyamasheke      14
# south_muhoza         14
# kigali_gasabo        14
# south_kamonyi        13
# east_nyagatare       13
# west_rusizi          13
# west_karongi         12
# east_kayonza         11
# south_huye           11
# south_nyaruguru      11
# west_nyabihu         11
# east_ngoma           10
# east_kirehe          10
# north_rulindo        10
# south_nyamagabe      10
# north_musanze        10
# kigali_nyarugenge     9
# south_ruhango         9
# west_rubavu           8
# east_gatsibo          8
# north_gicumbi         8
# north_gakenke         7
# west_ngororero        7
# east_bugesera         7
# kigali_kicukiro       7
# west_rutsiro          6
# south_nyanza          4
# north_burera          3
# Name: count, dtype: int64
# purchase_price
# 256.19    1
# 870.06    1
# 772.49    1
# 897.35    1
# 245.35    1
#          ..
# 734.61    1
# 323.62    1
# 544.23    1
# 497.54    1
# 953.99    1
# Name: count, Length: 300, dtype: int64
# purchase_date
# 2019-08-22    2
# 2018-08-24    2
# 2017-09-13    2
# 2023-09-06    2
# 2020-07-20    2
#              ..
# 2021-10-23    1
# 2019-12-11    1
# 2004-01-03    1
# 2009-08-01    1
# 2023-10-22    1
# Name: count, Length: 293, dtype: int64

# %%
df.fuel_type.value_counts()
# Out:
# fuel_type
# hybrid       49
# biodiesel    45
# gasoline     44
# diesel       42
# ethanol      42
# hydrogen     40
# electric     38
# Name: count, dtype: int64

# %%
df.columns.to_list()

# %%
df.rename(columns={'vin': 'Vehicle Identification Number'}, inplace=True)
df.to_csv('ml.csv')

# %%
df.dtypes
# Out:
# Unnamed: 0                         int64
# Vehicle Identification Number     object
# manufacturer                      object
# year                               int64
# color                             object
# body_type                         object
# engine_type                       object
# transmission                      object
# fuel_type                         object
# seating_capacity                   int64
# kilometers_driven                float64
# vehicle_condition_status          object
# selling_price                    float64
# owner_name                        object
# owner_profession                  object
# owner_age                          int64
# owner_district                    object
# purchase_price                   float64
# purchase_date                     object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# vin                         0
# manufacturer                0
# year                        0
# color                       0
# body_type                   0
# engine_type                 0
# transmission                0
# fuel_type                   0
# seating_capacity            0
# kilometers_driven           0
# vehicle_condition_status    0
# selling_price               0
# owner_name                  0
# owner_profession            0
# owner_age                   0
# owner_district              0
# purchase_price              0
# purchase_date               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'vin', 'manufacturer', 'year', 'color', 'body_type',
#        'engine_type', 'transmission', 'fuel_type', 'seating_capacity',
#        'kilometers_driven', 'vehicle_condition_status', 'selling_price',
#        'owner_name', 'owner_profession', 'owner_age', 'owner_district',
#        'purchase_price', 'purchase_date'],
#       dtype='object')

# %%
plt.figure(figsize = (20, 5))
sns.countplot(x='manufacturer', data=df.sort_values(by='manufacturer'), hue='manufacturer', palette='husl', legend=False)
plt.grid(color="green", linestyle="--", linewidth=0.5)
plt.title("Companies with their sold Vehicles", fontdict={"family": "serif", "color": "blue", "size": 20})
plt.xticks(rotation=45)  # Optional: Rotate x labels for better visibility
plt.show()

# %%
plt.figure(figsize = (20, 5))
sns.countplot(x='owner_district', data=df.sort_values(by='owner_district'), hue='owner_district', palette='colorblind', legend=False)
plt.grid(color="green", linestyle="--", linewidth=0.5)
plt.title("Districts with their Vehicles", fontdict={"family": "serif", "color": "blue", "size": 20})
plt.xticks(rotation=90)  # Optional: Rotate x labels for better visibility
plt.show()

# %%
plt.figure(figsize = (20, 5))
sns.countplot(x='color', data=df.sort_values(by='color'), hue='color', palette='Spectral', legend=False)
plt.grid(color="green", linestyle="--", linewidth=0.5)
plt.title("Distribution of Vehicles colors", fontdict={"family": "serif", "color": "blue", "size": 20})
plt.xticks(rotation=90)  # Optional: Rotate x labels for better visibility
plt.show()

# %%
# Assuming 'car_data' is your DataFrame and 'Year' is the column to count
plt.figure(figsize=(20, 5))
sns.countplot(x='year', data=df, hue='year', palette='dark', legend=False)  # Use 'x' for the column
plt.grid(color="green", linestyle="--", linewidth=0.5)
plt.title("Number of vehicles manufactured in different years", fontdict={"family": "serif", "color": "blue", "size": 20})
plt.xlabel("Year", fontsize=15)  # Optional: Label for the x-axis
plt.ylabel("Count", fontsize=15)  # Optional: Label for the y-axis
plt.xticks(rotation=45)  # Optional: Rotate x labels for better visibility
plt.show()

# %%
plt.figure(figsize=(18, 6))
sns.countplot(x='owner_age', data=df, hue='owner_age', palette='viridis', legend=False)
plt.grid(color="green", linestyle="--", linewidth=0.5)
plt.title("Vehicle owners age", fontdict={"family": "serif", "color": "blue", "size": 20})
plt.xticks(rotation=90)  # Optional: Rotate x labels for better visibility
plt.show()

# %%
plt.figure(figsize = (20, 5))
sns.countplot(x='owner_profession', data=df.sort_values(by='owner_profession'), hue='owner_profession', palette='colorblind', legend=False)
plt.grid(color="green", linestyle="--", linewidth=0.5)
plt.title("Distribution of vehicles by owner profession", fontdict={"family": "serif", "color": "blue", "size": 20})
plt.xticks(rotation=90)  # Optional: Rotate x labels for better visibility
plt.show()

# %%
plt.figure(figsize = (20, 5))
sns.countplot(x='fuel_type', data=df.sort_values(by='fuel_type'), hue='fuel_type', palette='Paired', legend=False)
plt.grid(color="green", linestyle="--", linewidth=0.5)
plt.title("Distribution of vehicles by their fuel type", fontdict={"family": "serif", "color": "blue", "size": 20})
plt.xticks(rotation=90)  # Optional: Rotate x labels for better visibility
plt.show()

# %%
df.nunique()
# Out:
# Unnamed: 0.1                     300
# Unnamed: 0                       300
# Vehicle Identification Number    300
# manufacturer                      10
# year                              11
# color                             23
# body_type                          8
# engine_type                        3
# transmission                       2
# fuel_type                          7
# seating_capacity                   9
# kilometers_driven                296
# vehicle_condition_status           2
# selling_price                    300
# owner_name                       123
# owner_profession                  86
# owner_age                         81
# owner_district                    30
# purchase_price                   300
# purchase_date                    293
# dtype: int64

# %%
df.groupby('manufacturer').agg({
    'seating_capacity': ['min', 'max', 'mean', 'std', 'first', 'last'],
    'selling_price': ['min', 'max', 'mean', 'std', 'sum'],
    'purchase_price': ['min', 'max', 'mean', 'std', 'sum']
})
# Out:
#              seating_capacity                                     \
#                           min max      mean       std first last
# manufacturer
# Audi                        2  10  6.222222  2.531077     5    2
# BMW                         2  10  6.666667  2.586949     9    7
# Chevrolet                   2  10  5.526316  2.424390     7    7
# Ford                        2  10  5.694444  2.616644     4   10
# Honda                       2  10  6.000000  2.491364     4    4
# Hyundai                     2  10  5.392857  2.739820    10    6
# Mercedes                    2  10  5.826087  2.902228    10    2
# Nissan                      2  10  5.833333  2.869126     4    6
# Toyota                      3  10  6.515152  2.032874     8    4
# Volkswagen                  2  10  6.320000  2.688246     8    2
#
#              selling_price                                             \
#                        min      max        mean         std       sum
# manufacturer
# Audi                 88.36  2000.12  554.322778  350.152216  19955.62
# BMW                 168.25   992.13  569.700741  255.918295  15381.92
# Chevrolet           135.29   992.28  602.965526  259.899726  22912.69
# Ford                133.47   975.05  608.697778  261.443790  21913.12
# Honda               212.83   997.24  550.010667  250.098030  16500.32
# Hyundai             206.41   955.24  595.131786  197.512169  16663.69
# Mercedes            240.94   970.38  600.273043  226.398335  13806.28
# Nissan               37.69   971.00  553.073333  232.098189  13273.76
# Toyota               42.06   951.89  549.473939  280.727469  18132.64
# Volkswagen          123.79   998.44  603.962800  254.042396  15099.07
#
#              purchase_price
#                         min      max        mean         std       sum
# manufacturer
# Audi                 125.40   988.15  563.035556  279.758350  20269.28
# BMW                  169.58  1050.54  633.928148  276.916575  17116.06
# Chevrolet            159.58  1188.86  684.278947  275.601923  26002.60
# Ford                 153.25  1129.86  666.085833  273.971826  23979.09
# Honda                248.70  1096.71  634.246000  252.430514  19027.38
# Hyundai              245.35  1007.69  656.353929  183.826258  18377.91
# Mercedes             240.94  1104.53  650.434783  246.638069  14960.00
# Nissan                37.69  1058.97  616.537917  256.950391  14796.91
# Toyota                42.06  1056.34  597.961818  303.008928  19732.74
# Volkswagen           171.29  1049.01  642.688400  254.068855  16067.21

# %%
plt.figure(figsize = (15, 4))
df.groupby('manufacturer')['purchase_price'].sum().plot(kind = 'pie', autopct='%1.1f%%', startangle=90, legend=False)
plt.title("The income in different manufacturers", fontsize = 20)
plt.show()

# %%
plt.figure(figsize=(20, 4))
earned_by_manufacturer = df.groupby('manufacturer')['purchase_price'].sum().sort_values(ascending = True).plot(kind='barh', color='g')
plt.title("Money earned from vehicle by manufacturer type", fontsize=20)
plt.xlabel("Manufacturer", fontsize=15)
plt.ylabel("Purchase Price", fontsize=15)
plt.xticks(rotation=45)  # Rotate x-tick labels for better visibility
plt.grid(color="green", linestyle="--", linewidth=0.5)
plt.show()

# %%
plt.figure(figsize=(20, 2))
earned_by_manufacturer = df.groupby('transmission')['purchase_price'].sum().plot(kind = 'barh', color = 'olivedrab')
plt.title("Money earned from vehicle by transmission type", fontsize=20)
plt.xlabel("Transmission type", fontsize=15)
plt.ylabel("Purchase Price", fontsize=15)
plt.grid(color="green", linestyle="--", linewidth=0.5)
plt.show()

# %%
plt.figure(figsize=(20, 3))
# Create scatter plot for selling_price
sns.scatterplot(x='selling_price', y='purchase_price', data=df, color='r', label='Selling Price', alpha=0.6)
# Create scatter plot for purchase_price
sns.scatterplot(x='purchase_price', y='selling_price', data=df, color='b', label='Purchase Price', alpha=0.6)
plt.title("Scatter Plot between Selling Price and Purchase Price", fontsize=20)
plt.grid(color="green", linestyle="--", linewidth=0.5)
plt.xlabel("Price", fontsize=15)
plt.ylabel("Price", fontsize=15)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20, 3))
# Create the scatter plot for selling_price vs. purchase_price
sns.scatterplot(x='selling_price', y='purchase_price', data=df, color='b', alpha=0.6)
plt.title("Scatter Plot between Selling Price and Purchase Price", fontsize=20)
plt.grid(color="green", linestyle="--", linewidth=0.5)
plt.xlabel("Selling Price", fontsize=15)
plt.ylabel("Purchase Price", fontsize=15)
plt.show()

# %%
plt.figure(figsize = (20, 3))
numeric_columns = ['owner_age', 'selling_price', 'purchase_price', 'year', 'kilometers_driven']
heatmap_data = df[numeric_columns].corr()
sns.heatmap(heatmap_data, cmap = 'BuPu', annot = True)
plt.show()

# %%
print('Correlation between selling_price and kilometers_driven:', df['selling_price'].corr(df['kilometers_driven']))
# Out:
# Correlation between selling_price and kilometers_driven: -0.05145279454179889

# %%
plt.figure(figsize = (20, 3))
sns.boxplot(data = df[['selling_price', 'purchase_price']], palette = 'Accent')
plt.title("Boxplot of selling_price and purchase_price", fontsize = 15)
plt.show()

# %%
# Return all outliers (greater than 1500 or less than 0)
df[df['selling_price'] > 1500]
# Out:
#      Unnamed: 0.1  Unnamed: 0 Vehicle Identification Number manufacturer  \
# 299           299         299             03Y6KT7Y3GRCXHQC8         Audi
#
#        year        color body_type engine_type transmission fuel_type  \
# 299  2000.0  matte_black     Coupe    electric    automatic  gasoline
#
#      seating_capacity  kilometers_driven vehicle_condition_status  \
# 299                 2               2.12                   active
#
#      selling_price      owner_name owner_profession  owner_age owner_district  \
# 299        2000.12  UMWALI Cynthia          surgeon         58   west_rutsiro
#
#      purchase_price purchase_date
# 299          953.99    2023-10-22

# %%
purchase_price_sum = df.groupby('manufacturer')['purchase_price'].sum()
plt.figure(figsize=(20, 3))
plt.bar(purchase_price_sum.index, purchase_price_sum.values, color=sns.color_palette("colorblind", len(purchase_price_sum)))
plt.grid(color="green", linestyle="--", linewidth=0.5)
plt.title("Total Purchase Price by Manufacturer", fontsize=20)
plt.xlabel("Manufacturer", fontsize=15)
plt.ylabel("Total Purchase Price", fontsize=15)
plt.show()

# %%
purchase_price_sum = df.groupby('body_type')['purchase_price'].sum()
plt.figure(figsize=(20, 3))
plt.bar(purchase_price_sum.index, purchase_price_sum.values, color=sns.color_palette("colorblind", len(purchase_price_sum)))
plt.grid(color="green", linestyle="--", linewidth=0.5)
plt.title("Total Purchase Price by body_type", fontsize=20)
plt.xlabel("Body type", fontsize=15)
plt.ylabel("Total Purchase Price", fontsize=15)
plt.show()

# %%
purchase_price_sum = df.groupby('engine_type')['purchase_price'].sum()
plt.figure(figsize=(20, 3))
plt.barh(purchase_price_sum.index, purchase_price_sum.values, color=sns.color_palette("husl", len(purchase_price_sum)))
plt.grid(color="green", linestyle="--", linewidth=0.5)
plt.title("Total Purchase Price by engine_type", fontsize=20)
plt.ylabel("Engine type", fontsize=15)
plt.xlabel("Total Purchase Price", fontsize=15)
plt.show()

# %%
purchase_price_sum = df.groupby('fuel_type')['purchase_price'].sum()
plt.figure(figsize=(20, 3))
plt.bar(purchase_price_sum.index, purchase_price_sum.values, color=sns.color_palette("husl", len(purchase_price_sum)))
plt.grid(color="green", linestyle="--", linewidth=0.5)
plt.title("Total Purchase Price by fuel_type", fontsize=20)
plt.xlabel("Fuel type", fontsize=15)
plt.ylabel("Total Purchase Price", fontsize=15)
plt.xticks(rotation=90)  # Rotate x labels for better readability
plt.show()

# %%
purchase_price_sum = df.groupby('owner_district')['purchase_price'].sum()
plt.figure(figsize=(20, 3))
plt.bar(purchase_price_sum.index, purchase_price_sum.values, color=sns.color_palette("husl", len(purchase_price_sum)))
plt.grid(color="green", linestyle="--", linewidth=0.5)
plt.title("Total Purchase Price by owner_district", fontsize=20)
plt.xlabel("District", fontsize=15)
plt.ylabel("Total Purchase Price", fontsize=15)
plt.xticks(rotation=90)  # Rotate x labels for better readability
plt.show()
